# %%
from visa_tracker import VisaTracker

tracker = VisaTracker()

tracker.check_and_save()
# Out:
# Loaded 5 existing hashes
# [2025-12-11 09:56:14.022379] Checking for visa processing updates...
# New data saved! Hash: a35d8afc...
#   Visa: Student visa (subclass 500)
#   75th percentile: 5 Months
#   90th percentile: 8 Months

# %%
from visualize_visa_times import main

plt = main()
plt.show()
# Out:
# Trend chart saved as: visa_processing_times_trend.svg
