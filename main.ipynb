# %%
from visa_tracker import VisaTracker

tracker = VisaTracker()

tracker.check_and_save()
# Out:
# Loaded 10 existing hashes
# [2026-05-25 11:01:18.181210] Checking for visa processing updates...
# New data saved! Hash: 2b217f4d...
#   Visa: Student visa (subclass 500)
#   75th percentile: 49 Days
#   90th percentile: 83 Days

# %%
from visualize_visa_times import main

plt = main()
plt.show()
# Out:
# Trend chart saved as: visa_processing_times_trend.svg
