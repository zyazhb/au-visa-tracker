# %%
from visa_tracker import VisaTracker

tracker = VisaTracker()

tracker.check_and_save()
# Out:
# Loaded 8 existing hashes
# [2026-03-24 13:19:10.396520] Checking for visa processing updates...
# New data saved! Hash: 72a68850...
#   Visa: Student visa (subclass 500)
#   75th percentile: 46 Days
#   90th percentile: 6 Months

# %%
from visualize_visa_times import main

plt = main()
plt.show()
# Out:
# Trend chart saved as: visa_processing_times_trend.svg
