# %%
from visa_tracker import VisaTracker

tracker = VisaTracker()

tracker.check_and_save()
# Out:
# Loaded 7 existing hashes
# [2026-03-06 15:47:58.431696] Checking for visa processing updates...
# New data saved! Hash: 8334346b...
#   Visa: Student visa (subclass 500)
#   75th percentile: 45 Days
#   90th percentile: 5 Months

# %%
from visualize_visa_times import main

plt = main()
plt.show()
# Out:
# Trend chart saved as: visa_processing_times_trend.svg
