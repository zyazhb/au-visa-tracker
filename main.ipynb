# %%
from visa_tracker import VisaTracker

tracker = VisaTracker()

tracker.check_and_save()
# Out:
# Loaded 5 existing hashes
# [2025-11-26 13:34:53.415426] Checking for visa processing updates...
# Data unchanged (hash: 6ddd2877...)

# %%
from visualize_visa_times import main

plt = main()
plt.show()
# Out:
# Trend chart saved as: visa_processing_times_trend.png
