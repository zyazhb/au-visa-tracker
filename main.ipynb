# %%
from visa_tracker import VisaTracker

tracker = VisaTracker()

tracker.check_and_save()
# Out:
# Loaded 6 existing hashes
# [2026-02-02 09:14:41.541385] Checking for visa processing updates...
# New data saved! Hash: d603413e...
#   Visa: Student visa (subclass 500)
#   75th percentile: 50 Days
#   90th percentile: 82 Days

# %%
from visualize_visa_times import main

plt = main()
plt.show()
# Out:
# Trend chart saved as: visa_processing_times_trend.svg
