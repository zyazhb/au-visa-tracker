# %%
from visa_tracker import VisaTracker

tracker = VisaTracker()

tracker.check_and_save()
# Out:
# Loaded 2 existing hashes
# [2025-08-22 21:07:34.116470] Checking for visa processing updates...
# New data saved! Hash: 12fea63a...
#   Visa: Student visa (subclass 500)
#   75th percentile: 5 Months
#   90th percentile: 11 Months

# %%
from visualize_visa_times import main

main()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Trend chart saved as: visa_processing_times_trend.png
